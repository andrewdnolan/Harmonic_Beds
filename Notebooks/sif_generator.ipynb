# %%
with open('../SRC/SIFs/Prognostic_SpinUp.sif', 'r') as file :
    filedata = file.read()

# %%
print(filedata)
# Out:
# !echo on
#
# #yearinsec = 365.25*24*60*60                        ![s a^-1]
# #rhoi      = 910.0                                  ![kg m^-3]
# #rhow      = 1000.0                                 ![kg m^-3]
#
# ! Variable updated via the bash run file
# $NT = 10
# $dt = 2.0
# $RUN = "Begin_Course_test"
# $BED = "Farinotti_smooth"
# $offset = 0.0
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ! BEGIN HEADER
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Header
#   CHECK KEYWORDS Warn
#   Mesh DB           "./Synthetic/"$BED"/" "mesh"   !\"
#   Include Path      "./Synthetic/"$BED"/Exp_01_elevation_dependent"          !\"
#   Results Directory "./Synthetic/"$BED"/Exp_01_elevation_dependent"          !\"
# End
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ! END HEADER
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# ...
